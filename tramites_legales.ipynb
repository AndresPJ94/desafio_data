# %%
import pandas as pd
import numpy as np

database=pd.read_csv("database.csv")

# %%
database
# Out:
#        ID   Nombre Apellidos                 Email   Password  \
# 0       1  ZpafJwb  IGLxqLcD  SidQXyFROW@gmail.com  FuDgmKsOA
# 1       2  vraVenl  pQgDlKpb  dmRMlEHSix@gmail.com  TcEDUaWhT
# 2       3  ZCogidr  pyqWoZEy  InOMyDalbC@gmail.com  YigDCDzGH
# 3       4  vdTiFuY  DsyOuIJT  zXBFBgHyDk@gmail.com  juZCtMEMk
# 4       5  sRnfLQq  sOAsLqnv  juObUXPbPT@gmail.com  IlpRnxgfA
# ..    ...      ...       ...                   ...        ...
# 995   996  qlAUinO  HkteZaeP  AXBsleUfMm@gmail.com  axiQOntoW
# 996   997  HnJMkKj  zuDhUceW  xxaMIjFCJW@gmail.com  peBKFtWWv
# 997   998  CktDljE  mCSwjuQK  OHaSQvtikD@gmail.com  RfLdDmCNU
# 998   999  wTYHViC  CdhuDXby  CAhscijQPr@gmail.com  zFeAKVmdk
# 999  1000  wROqzxk  KjObyhtA  UiyOneQQmF@gmail.com  PgnDmUYdd
#
#      Año de Nacimiento          Genero              Idioma  \
# 0                 1997        Femenino      Frances, Chino
# 1                 1983  No especificar       Aleman, Chino
# 2                 1998       Masculino   Portugues, Ingles
# 3                 1968        Femenino  Frances, Ucraniano
# 4                 1982  No especificar   Ucraniano, Ingles
# ..                 ...             ...                 ...
# 995               1976  No especificar              Aleman
# 996               1973  No especificar             Español
# 997               1974  No especificar              Aleman
# 998               1972       Masculino     Español, Aleman
# 999               1991        Femenino       Rumano, Arabe
#
#          Años en España           Nivel de Estudios         Trabajo  \
# 0     De 1 año a 2 años        Sin graduado escolar              Si
# 1     De 1 año a 2 años                      Master  No especificar
# 2      Menos de 6 meses                   Doctorado  No especificar
# 3    De 6 meses a 1 año  FP (Formacion Profesional)  No especificar
# 4    De 6 meses a 1 año        Sin graduado escolar              Si
# ..                  ...                         ...             ...
# 995    Menos de 6 meses         Grado universitario              Si
# 996       Más de 2 años         Grado universitario  No especificar
# 997       Más de 2 años         Grado universitario              Si
# 998  De 6 meses a 1 año        Sin graduado escolar  No especificar
# 999  De 6 meses a 1 año                   Doctorado  No especificar
#
#                         Tipo de Apoyo Experto Comarcas (Sierra Norte)  \
# 0                           Emocional      No        Valle del Jarama
# 1    Orientacion sobre temas  legales      Si   Valle Bajo del Lozoya
# 2                 Orientacion laboral      No       Sierra del Rincon
# 3          Orientación sobre trámites      Si  Valle Medio del Lozoya
# 4    Orientacion sobre temas  legales      Si   Valle Alto del Lozoya
# ..                                ...     ...                     ...
# 995                         Emocional      Si       Sierra del Rincon
# 996               Orientacion laboral      No        Valle del Jarama
# 997        Orientación sobre trámites      Si       Sierra del Rincon
# 998               Orientacion laboral      Si  Valle Medio del Lozoya
# 999                         Emocional      No        Valle del Jarama
#
#                       Sobre mi Fecha de Registro
# 0        Juegos, Baile, Musica        2021-10-13
# 1         Lectura, Baile, Cine        2021-07-12
# 2       Viajar, Baile, Lectura        2021-02-09
# 3     Deportes, Pintura, Baile        2022-08-24
# 4       Cocina, Juegos, Musica        2021-04-21
# ..                         ...               ...
# 995  Pintura, Cine, Naturaleza        2021-06-04
# 996  Juegos, Fotografia, Baile        2022-11-19
# 997    Musica, Pintura, Cocina        2021-09-04
# 998      Baile, Juegos, Viajar        2021-12-01
# 999  Cocina, Baile, Fotografia        2022-08-02
#
# [1000 rows x 16 columns]

# %% [markdown]
# EJEMPLO DE USUARIO (NOS PASAN ID)

# %%
id=int(input())

user=database.loc[database["ID"]==id,:]

#Convierto sus valores en lista para poder hacer mascaras a la hora de cruzar con el df general
listau=user.values.flatten().tolist()

listau
# Out:
# [13,
#  'tsUoVtD',
#  'pzWUHkCr',
#  'zXYobgZXKm@gmail.com',
#  'KLjugkLIB',
#  1966,
#  'Femenino',
#  'Ingles, Frances',
#  'De 1 año a 2 años',
#  'Doctorado',
#  'Si',
#  'Emocional',
#  'Si',
#  'Valle del Jarama',
#  'Fotografia, Viajar, Naturaleza',
#  '2021-08-15']

# %% [markdown]
# CREO UNA NUEVA TABLA DONDE SOLO ME CENTRO EN TIPOS DE APOYO TRAMITES/LEGALES

# %%
legal=database[database["Tipo de Apoyo"]=="Orientación sobre trámites"]
legal = legal.append(database[database["Tipo de Apoyo"]=="Orientacion sobre temas  legales"])
legal=legal.sort_values("ID")
legal
# Out:
# C:\Users\sesco\AppData\Local\Temp\ipykernel_19632\3697100015.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   legal = legal.append(database[database["Tipo de Apoyo"]=="Orientacion sobre temas  legales"])
#       ID   Nombre Apellidos                 Email   Password  \
# 1      2  vraVenl  pQgDlKpb  dmRMlEHSix@gmail.com  TcEDUaWhT
# 3      4  vdTiFuY  DsyOuIJT  zXBFBgHyDk@gmail.com  juZCtMEMk
# 4      5  sRnfLQq  sOAsLqnv  juObUXPbPT@gmail.com  IlpRnxgfA
# 5      6  mzMaFwG  aFluzzgb  TLUFIGikzn@gmail.com  pygSbGQYX
# 7      8  qUfSMUQ  ZiBYiGIV  IaaQlRmgjO@gmail.com  ZYsipCHZe
# ..   ...      ...       ...                   ...        ...
# 985  986  FIoNZgN  TUmkqcaM  nzvcvQboHi@gmail.com  JpTYFJvNW
# 986  987  fbJxMPs  mmDLcfyM  NDBTsNYsnR@gmail.com  fKrkauVED
# 987  988  ozyuqmJ  LisdHegR  CcHZLNENFV@gmail.com  LbLOtMKEX
# 989  990  VPpDfRQ  dXKeWHUi  NwWhDNVNgC@gmail.com  uTGsmPdtz
# 997  998  CktDljE  mCSwjuQK  OHaSQvtikD@gmail.com  RfLdDmCNU
#
#      Año de Nacimiento          Genero              Idioma  \
# 1                 1983  No especificar       Aleman, Chino
# 3                 1968        Femenino  Frances, Ucraniano
# 4                 1982  No especificar   Ucraniano, Ingles
# 5                 1980       Masculino       Chino, Aleman
# 7                 1966  No especificar             Español
# ..                 ...             ...                 ...
# 985               1992        Femenino               Arabe
# 986               1989  No especificar               Arabe
# 987               1970  No especificar      Ingles, Aleman
# 989               1989  No especificar           Portugues
# 997               1974  No especificar              Aleman
#
#          Años en España           Nivel de Estudios         Trabajo  \
# 1     De 1 año a 2 años                      Master  No especificar
# 3    De 6 meses a 1 año  FP (Formacion Profesional)  No especificar
# 4    De 6 meses a 1 año        Sin graduado escolar              Si
# 5         Más de 2 años                      Master  No especificar
# 7      Menos de 6 meses  FP (Formacion Profesional)              Si
# ..                  ...                         ...             ...
# 985       Más de 2 años                   Doctorado              No
# 986    Menos de 6 meses         Grado universitario              Si
# 987   De 1 año a 2 años        Sin graduado escolar              No
# 989  De 6 meses a 1 año                      Master              Si
# 997       Más de 2 años         Grado universitario              Si
#
#                         Tipo de Apoyo Experto Comarcas (Sierra Norte)  \
# 1    Orientacion sobre temas  legales      Si   Valle Bajo del Lozoya
# 3          Orientación sobre trámites      Si  Valle Medio del Lozoya
# 4    Orientacion sobre temas  legales      Si   Valle Alto del Lozoya
# 5    Orientacion sobre temas  legales      No  Valle Medio del Lozoya
# 7    Orientacion sobre temas  legales      Si   Valle Alto del Lozoya
# ..                                ...     ...                     ...
# 985        Orientación sobre trámites      No       Sierra del Rincon
# 986        Orientación sobre trámites      Si       Sierra del Rincon
# 987  Orientacion sobre temas  legales      Si        Valle del Jarama
# 989        Orientación sobre trámites      No   Valle Alto del Lozoya
# 997        Orientación sobre trámites      Si       Sierra del Rincon
#
#                           Sobre mi Fecha de Registro
# 1             Lectura, Baile, Cine        2021-07-12
# 3         Deportes, Pintura, Baile        2022-08-24
# 4           Cocina, Juegos, Musica        2021-04-21
# 5        Baile, Naturaleza, Musica        2021-02-26
# 7    Pintura, Deportes, Fotografia        2022-09-14
# ..                             ...               ...
# 985            Baile, Cine, Cocina        2021-02-26
# 986          Juegos, Baile, Viajar        2021-07-31
# 987      Naturaleza, Lectura, Cine        2021-07-13
# 989     Cocina, Naturaleza, Juegos        2021-12-12
# 997        Musica, Pintura, Cocina        2021-09-04
#
# [478 rows x 16 columns]

# %% [markdown]
# PARA NO PISARME, HAGO OTRO DF DONDE VOY A IR REALIZANDO ESTAS MASCARAS, FALTA EL TEMA IDIOMA Y PONER EN CADA IF UN ELSE QUE HAGA UN SORT VALUES DEL ANTERIOR.

# %% [markdown]
# ### Filtro -- Falta else en cada if

# %%
legal_us=legal

if legal_us.shape[0]>5:

    legal_us=legal_us[legal_us["Experto"]=="Si"]

    #if legal_us.shape()[0]>5:

        #legal_us=legal_us[legal_us["Idioma"]==]

    if legal_us.shape[0]>5:

        legal_us=legal_us[legal_us["Comarcas (Sierra Norte)"]==listau[13]]

        if legal_us.shape[0]>5:

            legal_us=legal_us[legal_us["Trabajo"]==listau[12]]

            if legal_us.shape[0]>5:

                legal_us=legal_us[legal_us["Años en España"]==listau[8]]

# %%
legal_us.head()
# Out:
#       ID   Nombre Apellidos                 Email   Password  \
# 116  117  BWjeOsb  kMASKCCD  wnEbHcIiHA@gmail.com  RBNaModIc
# 348  349  ZoNrDGn  LFZYVFGr  uZOqUJOBxt@gmail.com  mKBgeuDfY
# 946  947  pGyoGmZ  JtVdKFkk  JEWyGPRtyM@gmail.com  ykhVpGtGv
#
#      Año de Nacimiento          Genero            Idioma     Años en España  \
# 116               1998       Masculino  Portugues, Chino  De 1 año a 2 años
# 348               1964  No especificar   Italiano, Chino  De 1 año a 2 años
# 946               1965       Masculino            Ingles  De 1 año a 2 años
#
#        Nivel de Estudios Trabajo                     Tipo de Apoyo Experto  \
# 116            Doctorado      Si  Orientacion sobre temas  legales      Si
# 348  Grado universitario      Si  Orientacion sobre temas  legales      Si
# 946               Master      Si  Orientacion sobre temas  legales      Si
#
#     Comarcas (Sierra Norte)                     Sobre mi Fecha de Registro
# 116        Valle del Jarama  Viajar, Fotografia, Pintura        2022-06-10
# 348        Valle del Jarama    Baile, Fotografia, Musica        2022-01-10
# 946        Valle del Jarama     Musica, Cine, Fotografia        2021-03-29

# %%
#legal_us.sort_values(by= ["Comarcas (Sierra Norte)"]==listau[13])


#como cojones hago un sort_values de la columna pero que empiece por el valor que queremos??
legal.sort_values(by=["Comarcas (Sierra Norte)"])
# Out:
#       ID   Nombre Apellidos                 Email   Password  \
# 483  484  DbhabfC  coWZdtAC  UKlmsLWckJ@gmail.com  ClbMkctPm
# 211  212  sakMBbp  SNrInqHl  lkCzsJdwFP@gmail.com  UvMlOSSqH
# 204  205  tSyiUNp  EJkajDSn  ZpBCsZWMcb@gmail.com  RNBfDazgu
# 203  204  HKswcfK  yjLvkEJi  UCsEwqZURj@gmail.com  UhdtBnrsv
# 508  509  GjLTOwN  CvQDxIYi  MAAwRjOkBf@gmail.com  IXjBejOjx
# ..   ...      ...       ...                   ...        ...
# 736  737  yshLEke  mmmQGVZl  DUoDgSJmSW@gmail.com  XUQABdgoo
# 724  725  unQcBfh  gTgHUuDU  vQjCyYhSTd@gmail.com  udCPRVuRI
# 226  227  JgrwDHA  efXPONRL  PGAokANMTS@gmail.com  XWkfwrHJY
# 60    61  ksZolUR  AsNPQgGK  iKTgqvjIgD@gmail.com  TqtWiYWUg
# 789  790  uxFOIvt  NWuxOpZP  qIrTQMgYRh@gmail.com  IdsQpUFSN
#
#      Año de Nacimiento          Genero               Idioma  \
# 483               1972       Masculino               Ingles
# 211               1992  No especificar  Ucraniano, Italiano
# 204               1972       Masculino      Ingles, Frances
# 203               1974  No especificar    Aleman, Portugues
# 508               1977  No especificar               Ingles
# ..                 ...             ...                  ...
# 736               1985       Masculino   Frances, Ucraniano
# 724               1990        Femenino       Chino, Español
# 226               2001        Femenino              Frances
# 60                1999       Masculino                Chino
# 789               1976       Masculino  Italiano, Portugues
#
#          Años en España           Nivel de Estudios         Trabajo  \
# 483   De 1 año a 2 años                      Master  No especificar
# 211       Más de 2 años                      Master              No
# 204   De 1 año a 2 años         Grado universitario              No
# 203  De 6 meses a 1 año        Con graduado escolar  No especificar
# 508  De 6 meses a 1 año  FP (Formacion Profesional)              No
# ..                  ...                         ...             ...
# 736  De 6 meses a 1 año  FP (Formacion Profesional)              Si
# 724    Menos de 6 meses  FP (Formacion Profesional)              Si
# 226       Más de 2 años  FP (Formacion Profesional)  No especificar
# 60        Más de 2 años        Sin graduado escolar              Si
# 789       Más de 2 años  FP (Formacion Profesional)              No
#
#                         Tipo de Apoyo Experto Comarcas (Sierra Norte)  \
# 483  Orientacion sobre temas  legales      Si    Sierra de la Cabrera
# 211        Orientación sobre trámites      Si    Sierra de la Cabrera
# 204        Orientación sobre trámites      Si    Sierra de la Cabrera
# 203        Orientación sobre trámites      No    Sierra de la Cabrera
# 508        Orientación sobre trámites      No    Sierra de la Cabrera
# ..                                ...     ...                     ...
# 736        Orientación sobre trámites      No        Valle del Jarama
# 724        Orientación sobre trámites      Si        Valle del Jarama
# 226        Orientación sobre trámites      No        Valle del Jarama
# 60         Orientación sobre trámites      Si        Valle del Jarama
# 789  Orientacion sobre temas  legales      Si        Valle del Jarama
#
#                             Sobre mi Fecha de Registro
# 483          Lectura, Cocina, Musica        2022-02-14
# 211     Pintura, Lectura, Fotografia        2022-03-03
# 204  Pintura, Fotografia, Naturaleza        2022-12-11
# 203           Baile, Lectura, Juegos        2022-12-27
# 508          Musica, Lectura, Juegos        2021-05-03
# ..                               ...               ...
# 736        Juegos, Baile, Fotografia        2023-01-04
# 724    Fotografia, Deportes, Pintura        2022-01-08
# 226        Cocina, Baile, Fotografia        2021-11-19
# 60         Baile, Fotografia, Viajar        2022-05-13
# 789          Deportes, Baile, Juegos        2023-01-08
#
# [478 rows x 16 columns]

# %%
legal_us=legal

legal_us[legal_us["Años en España"]==listau[8]]
# Out:
#       ID   Nombre Apellidos                 Email   Password  \
# 3      4  vdTiFuY  DsyOuIJT  zXBFBgHyDk@gmail.com  juZCtMEMk
# 4      5  sRnfLQq  sOAsLqnv  juObUXPbPT@gmail.com  IlpRnxgfA
# 16    17  VAgXXyb  FIKFRZGM  CJiuvYoNiS@gmail.com  ZBRYXDSUs
# 32    33  ewfUXdK  mGKkLRac  lczimwUrqf@gmail.com  OLFVxHjNS
# 35    36  sCOZlxp  IEKocYWu  uygtVyIwxf@gmail.com  gxZSTUlmW
# ..   ...      ...       ...                   ...        ...
# 964  965  WpfAynS  qYWhwLuE  lCaoLMAgIk@gmail.com  vpRULYcVw
# 965  966  VbHanhf  LSjtDxHo  ahnrBTYLJq@gmail.com  DIHNoTLMg
# 975  976  ZUEDhRz  XGaDbNpf  mCpnuYhRFK@gmail.com  cAKSupxOo
# 981  982  dzYzjPn  WfTAhCeu  HMXpzEmNap@gmail.com  PrfLOAKVw
# 989  990  VPpDfRQ  dXKeWHUi  NwWhDNVNgC@gmail.com  uTGsmPdtz
#
#      Año de Nacimiento          Genero              Idioma  \
# 3                 1968        Femenino  Frances, Ucraniano
# 4                 1982  No especificar   Ucraniano, Ingles
# 16                1970  No especificar        Arabe, Chino
# 32                1985  No especificar               Arabe
# 35                1976        Femenino       Rumano, Chino
# ..                 ...             ...                 ...
# 964               1966       Masculino               Arabe
# 965               2003  No especificar            Italiano
# 975               1996  No especificar    Ingles, Italiano
# 981               1968       Masculino           Portugues
# 989               1989  No especificar           Portugues
#
#          Años en España           Nivel de Estudios         Trabajo  \
# 3    De 6 meses a 1 año  FP (Formacion Profesional)  No especificar
# 4    De 6 meses a 1 año        Sin graduado escolar              Si
# 16   De 6 meses a 1 año        Sin graduado escolar              Si
# 32   De 6 meses a 1 año        Con graduado escolar              Si
# 35   De 6 meses a 1 año                      Master              Si
# ..                  ...                         ...             ...
# 964  De 6 meses a 1 año        Con graduado escolar  No especificar
# 965  De 6 meses a 1 año                   Doctorado              No
# 975  De 6 meses a 1 año  FP (Formacion Profesional)              No
# 981  De 6 meses a 1 año                   Doctorado  No especificar
# 989  De 6 meses a 1 año                      Master              Si
#
#                         Tipo de Apoyo Experto Comarcas (Sierra Norte)  \
# 3          Orientación sobre trámites      Si  Valle Medio del Lozoya
# 4    Orientacion sobre temas  legales      Si   Valle Alto del Lozoya
# 16         Orientación sobre trámites      Si    Sierra de la Cabrera
# 32         Orientación sobre trámites      No       Sierra del Rincon
# 35         Orientación sobre trámites      No  Valle Medio del Lozoya
# ..                                ...     ...                     ...
# 964        Orientación sobre trámites      Si  Valle Medio del Lozoya
# 965        Orientación sobre trámites      No    Sierra de la Cabrera
# 975        Orientación sobre trámites      Si        Valle del Jarama
# 981  Orientacion sobre temas  legales      Si  Valle Medio del Lozoya
# 989        Orientación sobre trámites      No   Valle Alto del Lozoya
#
#                          Sobre mi Fecha de Registro
# 3        Deportes, Pintura, Baile        2022-08-24
# 4          Cocina, Juegos, Musica        2021-04-21
# 16   Naturaleza, Deportes, Cocina        2022-09-03
# 32   Musica, Naturaleza, Deportes        2022-10-17
# 35    Pintura, Fotografia, Viajar        2021-02-13
# ..                            ...               ...
# 964        Musica, Viajar, Cocina        2021-10-20
# 965           Cocina, Baile, Cine        2022-06-28
# 975        Musica, Cocina, Viajar        2021-06-13
# 981  Fotografia, Deportes, Viajar        2021-01-03
# 989    Cocina, Naturaleza, Juegos        2021-12-12
#
# [119 rows x 16 columns]
